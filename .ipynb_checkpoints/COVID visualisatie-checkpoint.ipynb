# %%
import os
import glob
import pandas as pd

# %%
os.chdir("C:/Users/benja/TIL6022---Project/data/covid_data")

# %%
pwd
# Out:
# 'C:\\Users\\benja\\TIL6022---Project\\data\\covid_data'

# %%
file_extension = '.csv'
all_filenames = [i for i in glob.glob(f"*{file_extension}")]

# %%
print(all_filenames)
# Out:
# ['COVID-19_aantallen_gemeente_per_dag_04102021_07102022.csv', 'COVID-19_aantallen_gemeente_per_dag_tm_03102021.csv']

# %%
a = all_filenames[-1]

# %%
import chardet
with open(a, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
df = pd.read_csv(a,                                                 #filename
                 encoding='utf-8',                                  #type of encoding used for our data
                 delimiter=';',                                     #how the data is seperated
                 parse_dates=['Date_of_publication'],               #make dates for the index_col
                 index_col='Date_of_publication'                    #the index column is the date of publication
                )                                          

#This cell is used to know how I want the dataframe to be made
#I will apply this code to the loop to combine all csv-files

# %%
df.head(5)
print(len(df.index))
# Out:
# 217248

# %%
combined_csv_covid = pd.concat([pd.read_csv(f, delimiter=';', parse_dates=['Date_of_publication'],
                 index_col='Date_of_publication') for f in all_filenames])

# %%
combined_csv_covid.shape
# Out:
# (354516, 11)

# %%
os.chdir('..')

# %%
pwd
# Out:
# 'C:\\Users\\benja\\TIL6022---Project\\data'

# %%
combined_csv_covid.to_csv('covid_combined.csv')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import read_csv
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
import matplotlib.dates as mdates
import datetime
import plotly.express as px

# %%
df = pd.read_csv('covid_combined.csv')

# %%
df.head()
# Out:
#   Date_of_publication  Version   Date_of_report Municipality_code  \
# 0          2021-04-10        6  7-10-2022 10:00            GM0014
# 1          2021-04-10        6  7-10-2022 10:00            GM0034
# 2          2021-04-10        6  7-10-2022 10:00            GM0037
# 3          2021-04-10        6  7-10-2022 10:00            GM0047
# 4          2021-04-10        6  7-10-2022 10:00            GM0050
#
#   Municipality_name   Province Security_region_code Security_region_name  \
# 0         Groningen  Groningen                 VR01            Groningen
# 1            Almere  Flevoland                 VR25            Flevoland
# 2       Stadskanaal  Groningen                 VR01            Groningen
# 3           Veendam  Groningen                 VR01            Groningen
# 4          Zeewolde  Flevoland                 VR25            Flevoland
#
#   Municipal_health_service                        ROAZ_region  Total_reported  \
# 0            GGD Groningen  Acute Zorgnetwerk Noord Nederland              14
# 1            GGD Flevoland                       SpoedZorgNet              21
# 2            GGD Groningen  Acute Zorgnetwerk Noord Nederland               2
# 3            GGD Groningen  Acute Zorgnetwerk Noord Nederland               2
# 4            GGD Flevoland                       SpoedZorgNet               0
#
#    Deceased
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
df.columns
# Out:
# Index(['Date_of_publication', 'Version', 'Date_of_report', 'Municipality_code',
#        'Municipality_name', 'Province', 'Security_region_code',
#        'Security_region_name', 'Municipal_health_service', 'ROAZ_region',
#        'Total_reported', 'Deceased'],
#       dtype='object')

# %%
df_new = df.query("Province == 'Zuid-Holland'")
df_day = df_new.groupby('Date_of_publication').sum() #df_covid_2 = df.query('Date_of_publication').sum()
df_day.head(5)

#date_convert = df3.index.strftime("%Y-%m")
#df_new_weekly = df.resample('W')
# Out:
#                      Version  Total_reported  Deceased
# Date_of_publication
# 2020-01-03               336               0         0
# 2020-01-04               336             239        18
# 2020-01-05               336             120        38
# 2020-01-06               336              34         0
# 2020-01-07               336              26         1

# %%
fig = px.line(df_day, 
              x=df_day.index, 
              y='Total_reported',
              title='Covid infections in South Holland'
             )
fig.show()
# Out:
# <div>                            <div id="17ed9e5d-7e14-4897-906b-6852f6dac7fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17ed9e5d-7e14-4897-906b-6852f6dac7fb")) {                    Plotly.newPlot(                        "17ed9e5d-7e14-4897-906b-6852f6dac7fb",                        [{"hovertemplate":"Date_of_publication=%{x}<br>Total_reported=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01-03","2020-01-04","2020-01-05","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-10","2020-01-11","2020-01-12","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-28","2020-02-29","2020-03-03","2020-03-04","2020-03-05","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-11","2020-03-12","2020-03-13","2020-03-14","2020-03-15","2020-03-16","2020-03-17","2020-03-18","2020-03-19","2020-03-20","2020-03-21","2020-03-22","2020-03-23","2020-03-24","2020-03-25","2020-03-26","2020-03-27","2020-03-28","2020-03-29","2020-03-30","2020-03-31","2020-04-03","2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29","2020-04-30","2020-05-03","2020-05-04","2020-05-05","2020-05-06","2020-05-07","2020-05-08","2020-05-09","2020-05-10","2020-05-11","2020-05-12","2020-05-13","2020-05-14","2020-05-15","2020-05-16","2020-05-17","2020-05-18","2020-05-19","2020-05-20","2020-05-21","2020-05-22","2020-05-23","2020-05-24","2020-05-25","2020-05-26","2020-05-27","2020-05-28","2020-05-29","2020-05-30","2020-05-31","2020-06-03","2020-06-04","2020-06-05","2020-06-06","2020-06-07","2020-06-08","2020-06-09","2020-06-10","2020-06-11","2020-06-12","2020-06-13","2020-06-14","2020-06-15","2020-06-16","2020-06-17","2020-06-18","2020-06-19","2020-06-20","2020-06-21","2020-06-22","2020-06-23","2020-06-24","2020-06-25","2020-06-26","2020-06-27","2020-06-28","2020-06-29","2020-06-30","2020-07-03","2020-07-04","2020-07-05","2020-07-06","2020-07-07","2020-07-08","2020-07-09","2020-07-10","2020-07-11","2020-07-12","2020-07-13","2020-07-14","2020-07-15","2020-07-16","2020-07-17","2020-07-18","2020-07-19","2020-07-20","2020-07-21","2020-07-22","2020-07-23","2020-07-24","2020-07-25","2020-07-26","2020-07-27","2020-07-28","2020-07-29","2020-07-30","2020-07-31","2020-08-03","2020-08-04","2020-08-05","2020-08-06","2020-08-07","2020-08-08","2020-08-09","2020-08-10","2020-08-11","2020-08-12","2020-08-13","2020-08-14","2020-08-15","2020-08-16","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-22","2020-08-23","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-29","2020-08-30","2020-08-31","2020-09-03","2020-09-04","2020-09-05","2020-09-06","2020-09-07","2020-09-08","2020-09-09","2020-09-10","2020-09-11","2020-09-12","2020-09-13","2020-09-14","2020-09-15","2020-09-16","2020-09-17","2020-09-18","2020-09-19","2020-09-20","2020-09-21","2020-09-22","2020-09-23","2020-09-24","2020-09-25","2020-09-26","2020-09-27","2020-09-28","2020-09-29","2020-09-30","2020-10-03","2020-10-04","2020-10-05","2020-10-06","2020-10-07","2020-10-08","2020-10-09","2020-10-10","2020-10-11","2020-10-12","2020-10-13","2020-10-14","2020-10-15","2020-10-16","2020-10-17","2020-10-18","2020-10-19","2020-10-20","2020-10-21","2020-10-22","2020-10-23","2020-10-24","2020-10-25","2020-10-26","2020-10-27","2020-10-28","2020-10 ...

# %%
df_day3 = df_day.drop(index='2022-08-02')
                 
fig = px.line(df_day3, 
              x=df_day3.index, 
              y='Total_reported',
              title='Covid infections in South Holland'
             )
fig.show()

#upper = np.where(df_day['Total_reported'] >= 40000)
#df_day.drop(upper)
# Out:
# <div>                            <div id="674752cc-15ea-4030-b0df-f736c5d7a812" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("674752cc-15ea-4030-b0df-f736c5d7a812")) {                    Plotly.newPlot(                        "674752cc-15ea-4030-b0df-f736c5d7a812",                        [{"hovertemplate":"Date_of_publication=%{x}<br>Total_reported=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01-03","2020-01-04","2020-01-05","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-10","2020-01-11","2020-01-12","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-28","2020-02-29","2020-03-03","2020-03-04","2020-03-05","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-11","2020-03-12","2020-03-13","2020-03-14","2020-03-15","2020-03-16","2020-03-17","2020-03-18","2020-03-19","2020-03-20","2020-03-21","2020-03-22","2020-03-23","2020-03-24","2020-03-25","2020-03-26","2020-03-27","2020-03-28","2020-03-29","2020-03-30","2020-03-31","2020-04-03","2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29","2020-04-30","2020-05-03","2020-05-04","2020-05-05","2020-05-06","2020-05-07","2020-05-08","2020-05-09","2020-05-10","2020-05-11","2020-05-12","2020-05-13","2020-05-14","2020-05-15","2020-05-16","2020-05-17","2020-05-18","2020-05-19","2020-05-20","2020-05-21","2020-05-22","2020-05-23","2020-05-24","2020-05-25","2020-05-26","2020-05-27","2020-05-28","2020-05-29","2020-05-30","2020-05-31","2020-06-03","2020-06-04","2020-06-05","2020-06-06","2020-06-07","2020-06-08","2020-06-09","2020-06-10","2020-06-11","2020-06-12","2020-06-13","2020-06-14","2020-06-15","2020-06-16","2020-06-17","2020-06-18","2020-06-19","2020-06-20","2020-06-21","2020-06-22","2020-06-23","2020-06-24","2020-06-25","2020-06-26","2020-06-27","2020-06-28","2020-06-29","2020-06-30","2020-07-03","2020-07-04","2020-07-05","2020-07-06","2020-07-07","2020-07-08","2020-07-09","2020-07-10","2020-07-11","2020-07-12","2020-07-13","2020-07-14","2020-07-15","2020-07-16","2020-07-17","2020-07-18","2020-07-19","2020-07-20","2020-07-21","2020-07-22","2020-07-23","2020-07-24","2020-07-25","2020-07-26","2020-07-27","2020-07-28","2020-07-29","2020-07-30","2020-07-31","2020-08-03","2020-08-04","2020-08-05","2020-08-06","2020-08-07","2020-08-08","2020-08-09","2020-08-10","2020-08-11","2020-08-12","2020-08-13","2020-08-14","2020-08-15","2020-08-16","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-22","2020-08-23","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-29","2020-08-30","2020-08-31","2020-09-03","2020-09-04","2020-09-05","2020-09-06","2020-09-07","2020-09-08","2020-09-09","2020-09-10","2020-09-11","2020-09-12","2020-09-13","2020-09-14","2020-09-15","2020-09-16","2020-09-17","2020-09-18","2020-09-19","2020-09-20","2020-09-21","2020-09-22","2020-09-23","2020-09-24","2020-09-25","2020-09-26","2020-09-27","2020-09-28","2020-09-29","2020-09-30","2020-10-03","2020-10-04","2020-10-05","2020-10-06","2020-10-07","2020-10-08","2020-10-09","2020-10-10","2020-10-11","2020-10-12","2020-10-13","2020-10-14","2020-10-15","2020-10-16","2020-10-17","2020-10-18","2020-10-19","2020-10-20","2020-10-21","2020-10-22","2020-10-23","2020-10-24","2020-10-25","2020-10-26","2020-10-27","2020-10-28","2020-10 ...
